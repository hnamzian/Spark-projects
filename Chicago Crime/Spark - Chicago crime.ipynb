# %%
import findspark
findspark.init()
from pyspark import SparkContext
from pyspark.sql import SQLContext, SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, BooleanType
from pyspark.sql.functions import unix_timestamp, year, month, dayofmonth, dayofyear

# %%
db_path = "I:/__Database__/Data Science/Crimes_-_2001_to_present.csv"

# %%
spark = SparkSession.builder \
        .master("local") \
        .appName("chicago") \
        .config("spark.some.config.option", "some-value") \
        .getOrCreate()

# %%
crime_schema = StructType([
    StructField("ID", StringType(), True),
    StructField("Case_Number", StringType(), True),
    StructField("Date", StringType(), True),
    StructField("Block", StringType(), True),
    StructField("IUCR", StringType(), True),
    StructField("Primary_Type", StringType(), True),
    StructField("Description", StringType(), True),
    StructField("Location_Description", StringType(), True),
    StructField("Arrest", StringType(), True),
    StructField("Domestic", StringType(), True),
    StructField("Beat", StringType(), True),
    StructField("District", StringType(), True),
    StructField("Ward", StringType(), True),
    StructField("Community_Area", StringType(), True),
    StructField("FBI_Code", StringType(), True),
    StructField("X_Coordinate", StringType(), True),
    StructField("Y_Coordinate", StringType(), True),
    StructField("Year", StringType(), True),
    StructField("Updated_On", StringType(), True),
    StructField("Latitude", StringType(), True),
    StructField("Longitude", StringType(), True),
    StructField("Location", StringType(), True),
])

crime_df = spark.read.csv(db_path, header=True, schema=crime_schema)

# %%
from_pattern = 'MM/dd/yyyy hh:mm:ss aa'
crime_df = crime_df.withColumn('DateTS', unix_timestamp(crime_df['Date'], from_pattern).cast("timestamp")).drop('Date')

# %%
crime_df.first()
# Out:
# Row(ID=u'2893074', Case_Number=u'HJ564203', Block=u'005XX W 36TH ST', IUCR=u'0610', Primary_Type=u'BURGLARY', Description=u'FORCIBLE ENTRY', Location_Description=u'RESIDENCE-GARAGE', Arrest=u'false', Domestic=u'false', Beat=u'0925', District=u'009', Ward=u'11', Community_Area=u'60', FBI_Code=u'05', X_Coordinate=u'1173107', Y_Coordinate=u'1881040', Year=u'2003', Updated_On=u'04/15/2016 08:55:02 AM', Latitude=u'41.829001329', Longitude=u'-87.640381824', Location=u'(41.829001329, -87.640381824)', DateTS=datetime.datetime(2003, 8, 15, 15, 0))

# %%
crime_df.groupBy(year(crime_df.DateTS)).count().orderBy("year(DateTS)").show()
# Out:
# +------------+------+
# |year(DateTS)| count|
# +------------+------+
# |        2001|485726|
# |        2002|486739|
# |        2003|475912|
# |        2004|469354|
# |        2005|453676|
# |        2006|448047|
# |        2007|436942|
# |        2008|426974|
# |        2009|392571|
# |        2010|370179|
# |        2011|351593|
# |        2012|335731|
# |        2013|306750|
# |        2014|274658|
# |        2015|263208|
# |        2016|267328|
# |        2017| 85371|
# +------------+------+

# %%
crime_df.groupBy(month(crime_df.DateTS)).count().orderBy("month(DateTS)").show()
# Out:
# +-------------+------+
# |month(DateTS)| count|
# +-------------+------+
# |            1|506713|
# |            2|445989|
# |            3|535471|
# |            4|536891|
# |            5|559609|
# |            6|551977|
# |            7|580414|
# |            8|574368|
# |            9|539600|
# |           10|547105|
# |           11|491285|
# |           12|461337|
# +-------------+------+

# %%
crime_df.groupBy("Ward").count().orderBy("count").show(1000)
# Out:
# +----+-----+
# |Ward|count|
# +----+-----+
# |0310|    5|
# |0430|   19|
# |1655|  767|
# |1652|  977|
# |1653| 2117|
# |0235| 2387|
# |1654| 2862|
# |0215| 3207|
# |1235| 3287|
# |1915| 3500|
# |1921| 3668|
# |1225| 3881|
# |1215| 3983|
# |1221| 4090|
# |0225| 4091|
# |1214| 4139|
# |0121| 4139|
# |1234| 4150|
# |0114| 4520|
# |1934| 4590|
# |1935| 4763|
# |1925| 5643|
# |1914| 5861|
# |1621| 6631|
# |2133| 7139|
# |2323| 8240|
# |2111| 8345|
# |2322| 8500|
# |1333| 8903|
# |1612| 8983|
# |2131| 9455|
# |2022| 9676|
# |1613| 9711|
# |2313| 9828|
# |1232|10079|
# |2312|10099|
# |2032|10109|
# |2324|10190|
# |1322|10297|
# |2033|10298|
# |2332|10354|
# |2012|10879|
# |1813|10931|
# |1611|10938|
# |0231|11067|
# |2112|11190|
# |2031|11210|
# |2333|11240|
# |2023|11784|
# |2331|11844|
# |1911|12237|
# |0434|12360|
# |1614|12634|
# |2513|12694|
# |0133|12700|
# |2013|12919|
# |2124|13173|
# |1922|13292|
# |2122|13467|
# |1332|13508|
# |1312|13531|
# |0921|13532|
# |0925|13757|
# |1313|13854|
# |1631|13864|
# |0214|13868|
# |2024|14039|
# |1912|14041|
# |1324|14093|
# |1032|14103|
# |1125|14384|
# |0224|14571|
# |1814|14640|
# |2431|14867|
# |1311|14947|
# |1233|15182|
# |1711|15206|
# |0124|15353|
# |0213|15465|
# |0221|15503|
# |1632|15536|
# |1414|15829|
# |2311|15924|
# |1431|16016|
# |0812|16136|
# |1713|16136|
# |1931|16234|
# |0311|16270|
# |0223|16294|
# |2132|16368|
# |2511|16439|
# |1114|16499|
# |2123|16557|
# |1213|16618|
# |2423|16716|
# |1331|16736|
# |1812|16827|
# |2525|17130|
# |1932|17148|
# |0134|17150|
# |2113|17309|
# |1413|17446|
# |0234|17475|
# |1222|17481|
# |1811|17487|
# |1651|17549|
# |2213|17562|
# |1023|17598|
# |1411|17636|
# |1724|17648|
# |0933|17649|
# |0633|17849|
# |2211|17928|
# |0113|18138|
# |0931|18313|
# |1513|18630|
# |0923|18636|
# |1412|18643|
# |1212|18646|
# |0232|18708|
# |1224|18721|
# |0222|18728|
# |0715|18783|
# |1033|18853|
# |1223|18997|
# |0622|19009|
# |1323|19014|
# |2424|19055|
# |0112|19090|
# |2011|19142|
# |1733|19230|
# |0433|19269|
# |0314|19335|
# |0821|19385|
# |1624|19495|
# |0811|19645|
# |1933|20040|
# |2524|20067|
# |0722|20073|
# |2523|20089|
# |1231|20114|
# |2411|20289|
# |0911|20299|
# |0233|20302|
# |0922|20306|
# |1832|20362|
# |2221|20376|
# |0732|20385|
# |1722|20407|
# |1913|20518|
# |0734|20551|
# |0714|20552|
# |0333|20566|
# |2412|20700|
# |1623|20716|
# |0212|20834|
# |1432|21051|
# |0724|21053|
# |1634|21112|
# |0731|21188|
# |1013|21362|
# |0924|21403|
# |1131|21571|
# |1512|21600|
# |0932|21669|
# |0131|21684|
# |1923|21754|
# |1034|21795|
# |1421|21824|
# |1012|21850|
# |2432|21929|
# |1622|21931|
# |1014|21950|
# |1732|21959|
# |0935|22013|
# |1731|22052|
# |0814|22066|
# |0532|22082|
# |0211|22123|
# |2433|22191|
# |1924|22291|
# |0913|22367|
# |2522|22422|
# |0111|22427|
# |1823|22718|
# |0915|22726|
# |1115|22853|
# |0334|22936|
# |2514|23041|
# |1024|23104|
# |1511|23203|
# |1124|23283|
# |0123|23288|
# |1031|23324|
# |1433|23520|
# |2531|23561|
# |1712|23567|
# |1423|23585|
# |0934|23647|
# |0726|23649|
# |2233|23701|
# |1633|23887|
# |0531|23933|
# |0614|24165|
# |1824|24222|
# |1434|24222|
# |1123|24564|
# |2232|24635|
# |1134|24649|
# |1821|24846|
# |1822|24930|
# |0634|24996|
# |0914|25067|
# |2222|25089|
# |0322|25242|
# |2223|25262|
# |0822|25271|
# |1022|25440|
# |0411|25518|
# |1211|25531|
# |1424|25565|
# |0422|25898|
# |2422|26040|
# |2515|26061|
# |0432|26068|
# |1021|26130|
# |1422|26156|
# |1833|26181|
# |2234|26320|
# |0735|26469|
# |0413|26619|
# |0733|27042|
# |0431|27051|
# |1135|27074|
# |2413|27097|
# |2212|27175|
# |0723|27423|
# |0533|27449|
# |1723|27504|
# |0332|27886|
# |0613|28082|
# |1113|28089|
# |0711|28121|
# |2521|28169|
# |0331|28478|
# |2532|28587|
# |0912|28631|
# |1524|28661|
# |0524|28854|
# |1111|29044|
# |2535|29126|
# |0815|29390|
# |0412|29410|
# |0835|29484|
# |0323|29538|
# |0424|29740|
# |0313|29785|
# |2512|29880|
# |0824|29962|
# |0834|30040|
# |1132|30135|
# |1831|30207|
# |0132|30213|
# |0611|30745|
# |0725|30880|
# |1133|30984|
# |0523|31195|
# |0813|31643|
# |0122|31775|
# |0623|31841|
# |2534|32023|
# |0513|32027|
# |1523|32043|
# |0632|32279|
# |0833|32605|
# |0324|32872|
# |0832|33277|
# |0312|33307|
# |1011|33495|
# |0712|33779|
# |1121|33791|
# |1122|33803|
# |0831|34230|
# |0631|34750|
# |1531|35676|
# |1532|35940|
# |0512|36253|
# |0713|36533|
# |0522|36894|
# |0612|37633|
# |0321|37640|
# |0825|37926|
# |0621|38050|
# |1834|38389|
# |2533|39219|
# |0414|40256|
# |1522|40260|
# |1112|41923|
# |0511|42168|
# |0823|42745|
# |1533|42854|
# |0624|43797|
# |0421|48313|
# |0423|49677|
# +----+-----+

# %%
crime_df.groupBy("Beat").count().orderBy("Beat").show()
# Out:
# +-----+-------+
# | Beat|  count|
# +-----+-------+
# |false|5512611|
# | true| 818148|
# +-----+-------+

# %%
crime_df.groupBy("Primary_Type").count().orderBy("count").show(1000, truncate=False)
# Out:
# +---------------------------------+-------+
# |Primary_Type                     |count  |
# +---------------------------------+-------+
# |DOMESTIC VIOLENCE                |1      |
# |NON-CRIMINAL (SUBJECT SPECIFIED) |7      |
# |RITUALISM                        |23     |
# |HUMAN TRAFFICKING                |32     |
# |NON - CRIMINAL                   |38     |
# |NON-CRIMINAL                     |99     |
# |CONCEALED CARRY LICENSE VIOLATION|105    |
# |OTHER NARCOTIC VIOLATION         |113    |
# |PUBLIC INDECENCY                 |144    |
# |OBSCENITY                        |438    |
# |STALKING                         |3084   |
# |INTIMIDATION                     |3687   |
# |KIDNAPPING                       |6388   |
# |HOMICIDE                         |8435   |
# |ARSON                            |10544  |
# |INTERFERENCE WITH PUBLIC OFFICER |13266  |
# |LIQUOR LAW VIOLATION             |13691  |
# |GAMBLING                         |14073  |
# |SEX OFFENSE                      |23229  |
# |CRIM SEXUAL ASSAULT              |24340  |
# |OFFENSE INVOLVING CHILDREN       |41394  |
# |PUBLIC PEACE VIOLATION           |45616  |
# |WEAPONS VIOLATION                |62672  |
# |PROSTITUTION                     |67261  |
# |CRIMINAL TRESPASS                |182841 |
# |DECEPTIVE PRACTICE               |231641 |
# |ROBBERY                          |239090 |
# |MOTOR VEHICLE THEFT              |298142 |
# |BURGLARY                         |369166 |
# |ASSAULT                          |387461 |
# |OTHER OFFENSE                    |392622 |
# |NARCOTICS                        |691194 |
# |CRIMINAL DAMAGE                  |727742 |
# |BATTERY                          |1155193|
# |THEFT                            |1316987|
# +---------------------------------+-------+

# %%
crime_df.groupBy("Location_Description").count().orderBy("count").show(1000, False)
# Out:
# +-----------------------------------------------+-------+
# |Location_Description                           |count  |
# +-----------------------------------------------+-------+
# |TRUCKING TERMINAL                              |1      |
# |CLEANERS/LAUNDROMAT                            |1      |
# |EXPRESSWAY EMBANKMENT                          |1      |
# |POOLROOM                                       |1      |
# |ELEVATOR                                       |1      |
# |JUNK YARD/GARBAGE DUMP                         |1      |
# |PUBLIC GRAMMAR SCHOOL                          |1      |
# |LAGOON                                         |1      |
# |FUNERAL PARLOR                                 |1      |
# |AUTO / BOAT / RV DEALERSHIP                    |1      |
# |LIVERY AUTO                                    |1      |
# |LOADING DOCK                                   |1      |
# |BANQUET HALL                                   |1      |
# |GOVERNMENT BUILDING                            |1      |
# |ROOMING HOUSE                                  |1      |
# |"CTA ""L"" TRAIN"                              |2      |
# |PUBLIC HIGH SCHOOL                             |2      |
# |COUNTY JAIL                                    |2      |
# |FACTORY                                        |2      |
# |CHURCH PROPERTY                                |2      |
# |CHA ELEVATOR                                   |2      |
# |RIVER BANK                                     |2      |
# |YMCA                                           |2      |
# |LAUNDRY ROOM                                   |2      |
# |CTA PROPERTY                                   |2      |
# |PRAIRIE                                        |2      |
# |LIVERY STAND OFFICE                            |2      |
# |CHA PLAY LOT                                   |3      |
# |CHA BREEZEWAY                                  |3      |
# |LAKE                                           |3      |
# |TRAILER                                        |3      |
# |COACH HOUSE                                    |3      |
# |SEWER                                          |3      |
# |"CTA ""L"" PLATFORM"                           |3      |
# |CHURCH                                         |4      |
# |RIVER                                          |4      |
# |HOSPITAL                                       |5      |
# |MOTEL                                          |5      |
# |NURSING HOME                                   |5      |
# |WOODED AREA                                    |5      |
# |CHA LOBBY                                      |6      |
# |TAXI CAB                                       |6      |
# |LIQUOR STORE                                   |6      |
# |DUMPSTER                                       |7      |
# |CHA STAIRWELL                                  |8      |
# |TRUCK                                          |8      |
# |GARAGE/AUTO REPAIR                             |9      |
# |SCHOOL YARD                                    |10     |
# |BARBER SHOP/BEAUTY SALON                       |12     |
# |RAILROAD PROPERTY                              |13     |
# |DRIVEWAY                                       |14     |
# |OFFICE                                         |14     |
# |STAIRWELL                                      |15     |
# |HOTEL                                          |15     |
# |CLUB                                           |15     |
# |VESTIBULE                                      |16     |
# |BASEMENT                                       |29     |
# |TAVERN                                         |33     |
# |CHA HALLWAY                                    |35     |
# |CHA PARKING LOT                                |38     |
# |CHA GROUNDS                                    |38     |
# |GAS STATION DRIVE/PROP.                        |42     |
# |VEHICLE - DELIVERY TRUCK                       |47     |
# |GARAGE                                         |48     |
# |CTA TRACKS - RIGHT OF WAY                      |55     |
# |AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA   |61     |
# |GANGWAY                                        |62     |
# |RETAIL STORE                                   |68     |
# |AIRPORT TRANSPORTATION SYSTEM (ATS)            |73     |
# |HALLWAY                                        |80     |
# |VACANT LOT                                     |93     |
# |PARKING LOT                                    |140    |
# |YARD                                           |172    |
# |NEWSSTAND                                      |219    |
# |AIRPORT EXTERIOR - SECURE AREA                 |225    |
# |VEHICLE - OTHER RIDE SERVICE                   |237    |
# |PORCH                                          |256    |
# |CEMETARY                                       |325    |
# |SAVINGS AND LOAN                               |334    |
# |BRIDGE                                         |346    |
# |FOREST PRESERVE                                |368    |
# |AIRPORT BUILDING NON-TERMINAL - SECURE AREA    |397    |
# |PAWN SHOP                                      |448    |
# |CREDIT UNION                                   |458    |
# |AIRPORT TERMINAL LOWER LEVEL - SECURE AREA     |486    |
# |HOUSE                                          |486    |
# |AIRCRAFT                                       |501    |
# |AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA |501    |
# |AIRPORT PARKING LOT                            |530    |
# |AIRPORT EXTERIOR - NON-SECURE AREA             |566    |
# |AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA|587    |
# |BOAT/WATERCRAFT                                |608    |
# |BOWLING ALLEY                                  |618    |
# |ANIMAL HOSPITAL                                |679    |
# |FEDERAL BUILDING                               |716    |
# |AIRPORT VENDING ESTABLISHMENT                  |732    |
# |POOL ROOM                                      |796    |
# |JAIL / LOCK-UP FACILITY                        |928    |
# |HIGHWAY/EXPRESSWAY                             |940    |
# |FIRE STATION                                   |952    |
# |DELIVERY TRUCK                                 |962    |
# |LAKEFRONT/WATERFRONT/RIVERBANK                 |972    |
# |COIN OPERATED MACHINE                          |980    |
# |AUTO                                           |1019   |
# |COLLEGE/UNIVERSITY RESIDENCE HALL              |1307   |
# |AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA |1322   |
# |APPLIANCE STORE                                |1638   |
# |CTA STATION                                    |2199   |
# |null                                           |2349   |
# |MOVIE HOUSE/THEATER                            |2362   |
# |DAY CARE CENTER                                |2448   |
# |CAR WASH                                       |2555   |
# |OTHER COMMERCIAL TRANSPORTATION                |2684   |
# |AIRPORT TERMINAL UPPER LEVEL - SECURE AREA     |3444   |
# |SCHOOL, PRIVATE, GROUNDS                       |3804   |
# |SPORTS ARENA/STADIUM                           |4581   |
# |CLEANING STORE                                 |4603   |
# |VEHICLE-COMMERCIAL                             |4950   |
# |CTA BUS STOP                                   |5239   |
# |COLLEGE/UNIVERSITY GROUNDS                     |5384   |
# |OTHER RAILROAD PROP / TRAIN DEPOT              |5425   |
# |LIBRARY                                        |5577   |
# |FACTORY/MANUFACTURING BUILDING                 |6561   |
# |TAXICAB                                        |6648   |
# |MEDICAL/DENTAL OFFICE                          |6682   |
# |ATM (AUTOMATIC TELLER MACHINE)                 |6778   |
# |BARBERSHOP                                     |7330   |
# |ATHLETIC CLUB                                  |7352   |
# |WAREHOUSE                                      |8757   |
# |CTA GARAGE / OTHER PROPERTY                    |9535   |
# |CURRENCY EXCHANGE                              |10169  |
# |ABANDONED BUILDING                             |10670  |
# |NURSING HOME/RETIREMENT HOME                   |12119  |
# |CONSTRUCTION SITE                              |12271  |
# |SCHOOL, PRIVATE, BUILDING                      |12564  |
# |CONVENIENCE STORE                              |12956  |
# |GOVERNMENT BUILDING/PROPERTY                   |13237  |
# |CHURCH/SYNAGOGUE/PLACE OF WORSHIP              |13981  |
# |POLICE FACILITY/VEH PARKING LOT                |15977  |
# |AIRPORT/AIRCRAFT                               |16012  |
# |HOSPITAL BUILDING/GROUNDS                      |18472  |
# |DRIVEWAY - RESIDENTIAL                         |18485  |
# |CTA BUS                                        |20213  |
# |CTA TRAIN                                      |20986  |
# |TAVERN/LIQUOR STORE                            |21004  |
# |VACANT LOT/LAND                                |22771  |
# |CHA HALLWAY/STAIRWELL/ELEVATOR                 |24558  |
# |HOTEL/MOTEL                                    |25741  |
# |BANK                                           |25813  |
# |SCHOOL, PUBLIC, GROUNDS                        |27415  |
# |DRUG STORE                                     |28769  |
# |BAR OR TAVERN                                  |32778  |
# |CTA PLATFORM                                   |34857  |
# |CHA APARTMENT                                  |34891  |
# |COMMERCIAL / BUSINESS OFFICE                   |46538  |
# |PARK PROPERTY                                  |48921  |
# |CHA PARKING LOT/GROUNDS                        |54562  |
# |RESIDENTIAL YARD (FRONT/BACK)                  |61006  |
# |GAS STATION                                    |66075  |
# |DEPARTMENT STORE                               |76460  |
# |GROCERY FOOD STORE                             |81980  |
# |RESTAURANT                                     |94493  |
# |VEHICLE NON-COMMERCIAL                         |100551 |
# |SMALL RETAIL STORE                             |108178 |
# |RESIDENCE PORCH/HALLWAY                        |110693 |
# |RESIDENCE-GARAGE                               |125099 |
# |SCHOOL, PUBLIC, BUILDING                       |137380 |
# |ALLEY                                          |142824 |
# |PARKING LOT/GARAGE(NON.RESID.)                 |181472 |
# |OTHER                                          |239210 |
# |SIDEWALK                                       |631669 |
# |APARTMENT                                      |645364 |
# |RESIDENCE                                      |1071989|
# |STREET                                         |1678524|
# +-----------------------------------------------+-------+
