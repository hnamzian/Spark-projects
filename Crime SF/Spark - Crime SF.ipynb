# %%
import findspark
findspark.init()
from pyspark import SparkContext
from pyspark.sql import SQLContext, SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, BooleanType, DateType
from pyspark.sql.functions import unix_timestamp, year, month, dayofmonth, dayofyear
from pyspark.ml.feature import StringIndexer

# %% [markdown]
# # DF preparation

# %%
train_path = "./data/train.csv"
test_path = "./data/test.csv"

# %%
spark = SparkSession.builder \
        .master("local") \
        .appName("chicago") \
        .config("spark.some.config.option", "some-value") \
        .getOrCreate()

# %%
train_schema = StructType([
    StructField("Dates", DateType(), True),
    StructField("Category", StringType(), True),
    StructField("Descript", StringType(), True),
    StructField("DayOfWeek", StringType(), True),
    StructField("PdDistrict", StringType(), True),
    StructField("Resolution", StringType(), True),
    StructField("Address", StringType(), True),
    StructField("X", StringType(), True),
    StructField("Y", StringType(), True)])
train = spark.read.csv(train_path, header=True, schema=train_schema)
train.first()
# Out:
# Row(Dates=datetime.date(2015, 5, 13), Category=u'WARRANTS', Descript=u'WARRANT ARREST', DayOfWeek=u'Wednesday', PdDistrict=u'NORTHERN', Resolution=u'ARREST, BOOKED', Address=u'OAK ST / LAGUNA ST', X=u'-122.425891675136', Y=u'37.7745985956747')

# %%
category_indexer = StringIndexer(inputCol="Category", outputCol="CategoryIndex")
Descript_indexer = StringIndexer(inputCol="Descript", outputCol="DescriptIndex")
PdDistrict_indexer = StringIndexer(inputCol="PdDistrict", outputCol="PdDistrictIndex")
Resolution_indexer = StringIndexer(inputCol="Resolution", outputCol="ResolutionIndex")
Address_indexer = StringIndexer(inputCol="Address", outputCol="AddressIndex")
DayOfWeek_indexer = StringIndexer(inputCol="DayOfWeek", outputCol="DayOfWeekIndex")

train = category_indexer.fit(train).transform(train)
train = Descript_indexer.fit(train).transform(train)
train = PdDistrict_indexer.fit(train).transform(train)
train = Resolution_indexer.fit(train).transform(train)
train = Address_indexer.fit(train).transform(train)
train = DayOfWeek_indexer.fit(train).transform(train)

train.first()
# Out:
# Row(Dates=datetime.date(2015, 5, 13), Category=u'WARRANTS', Descript=u'WARRANT ARREST', DayOfWeek=u'Wednesday', PdDistrict=u'NORTHERN', Resolution=u'ARREST, BOOKED', Address=u'OAK ST / LAGUNA ST', X=u'-122.425891675136', Y=u'37.7745985956747', CategoryIndex=7.0, DescriptIndex=5.0, PdDistrictIndex=2.0, ResolutionIndex=1.0, AddressIndex=3991.0, DayOfWeekIndex=1.0)

# %%
test_schema = StructType([
    StructField("Dates", DateType(), True),
    StructField("Category", StringType(), True),
    StructField("Descript", StringType(), True),
    StructField("DayOfWeek", StringType(), True),
    StructField("PdDistrict", StringType(), True),
    StructField("Address", StringType(), True),
    StructField("X", StringType(), True),
    StructField("Y", StringType(), True)])
test = spark.read.csv(test_path, header=True, inferSchema=True)
test.first()
# Out:
# Row(Id=0, Dates=datetime.datetime(2015, 5, 10, 23, 59), DayOfWeek=u'Sunday', PdDistrict=u'BAYVIEW', Address=u'2000 Block of THOMAS AV', X=-122.39958770418998, Y=37.7350510103906)

# %% [markdown]
# # EDA

# %% [markdown]
# ## number of crimes of each year

# %%
train.groupBy(year("Dates")).count().orderBy("year(Dates)").show()
# Out:
# +-----------+-----+
# |year(Dates)|count|
# +-----------+-----+
# |       2003|73902|
# |       2004|73422|
# |       2005|70779|
# |       2006|69909|
# |       2007|68015|
# |       2008|70174|
# |       2009|69000|
# |       2010|66542|
# |       2011|66619|
# |       2012|71731|
# |       2013|75606|
# |       2014|74766|
# |       2015|27584|
# +-----------+-----+

# %% [markdown]
# ## crime distribution of Addresses

# %%
train.groupBy("Address").count().orderBy("count", ascending=0).show(100000, truncate=False)
# Out:
# +--------------------------------------------+-----+
# |Address                                     |count|
# +--------------------------------------------+-----+
# |800 Block of BRYANT ST                      |26533|
# |800 Block of MARKET ST                      |6581 |
# |2000 Block of MISSION ST                    |5097 |
# |1000 Block of POTRERO AV                    |4063 |
# |900 Block of MARKET ST                      |3251 |
# |0 Block of TURK ST                          |3228 |
# |0 Block of 6TH ST                           |2884 |
# |300 Block of ELLIS ST                       |2703 |
# |400 Block of ELLIS ST                       |2590 |
# |16TH ST / MISSION ST                        |2504 |
# |1000 Block of MARKET ST                     |2489 |
# |1100 Block of MARKET ST                     |2319 |
# |2000 Block of MARKET ST                     |2168 |
# |100 Block of OFARRELL ST                    |2140 |
# |700 Block of MARKET ST                      |2081 |
# |3200 Block of 20TH AV                       |2035 |
# |100 Block of 6TH ST                         |1887 |
# |500 Block of JOHNFKENNEDY DR                |1824 |
# |TURK ST / TAYLOR ST                         |1810 |
# |200 Block of TURK ST                        |1800 |
# |0 Block of PHELAN AV                        |1791 |
# |0 Block of UNITEDNATIONS PZ                 |1789 |
# |0 Block of POWELL ST                        |1717 |
# |100 Block of EDDY ST                        |1681 |
# |1400 Block of PHELPS ST                     |1629 |
# |300 Block of EDDY ST                        |1589 |
# |100 Block of GOLDEN GATE AV                 |1353 |
# |100 Block of POWELL ST                      |1333 |
# |200 Block of INTERSTATE80 HY                |1316 |
# |MISSION ST / 16TH ST                        |1300 |
# |200 Block of EDDY ST                        |1294 |
# |900 Block of POTRERO AV                     |1290 |
# |100 Block of TURK ST                        |1286 |
# |2300 Block of 16TH ST                       |1281 |
# |400 Block of EDDY ST                        |1246 |
# |600 Block of VALENCIA ST                    |1234 |
# |700 Block of STANYAN ST                     |1226 |
# |3300 Block of MISSION ST                    |1210 |
# |400 Block of OFARRELL ST                    |1196 |
# |ELLIS ST / JONES ST                         |1185 |
# |0 Block of JONES ST                         |1185 |
# |0 Block of OFARRELL ST                      |1174 |
# |100 Block of TAYLOR ST                      |1172 |
# |3000 Block of 16TH ST                       |1164 |
# |1200 Block of MARKET ST                     |1114 |
# |400 Block of CASTRO ST                      |1078 |
# |100 Block of LEAVENWORTH ST                 |1076 |
# |400 Block of JONES ST                       |1075 |
# |1600 Block of THE EMBARCADERONORTH ST       |1057 |
# |TURK ST / LEAVENWORTH ST                    |1039 |
# |1300 Block of WEBSTER ST                    |995  |
# |100 Block of HYDE ST                        |993  |
# |1000 Block of MISSION ST                    |987  |
# |0 Block of GROVE ST                         |984  |
# |400 Block of BROADWAY ST                    |978  |
# |1900 Block of MISSION ST                    |962  |
# |2200 Block of MISSION ST                    |954  |
# |200 Block of GOLDEN GATE AV                 |951  |
# |800 Block of MISSION ST                     |918  |
# |0 Block of MASON ST                         |910  |
# |300 Block of LEAVENWORTH ST                 |899  |
# |24TH ST / MISSION ST                        |887  |
# |300 Block of OFARRELL ST                    |887  |
# |2100 Block of MISSION ST                    |868  |
# |300 Block of POWELL ST                      |860  |
# |7TH ST / MARKET ST                          |860  |
# |500 Block of OFARRELL ST                    |855  |
# |1100 Block of FILLMORE ST                   |850  |
# |200 Block of LEAVENWORTH ST                 |841  |
# |400 Block of TURK ST                        |822  |
# |MARKET ST / 7TH ST                          |812  |
# |600 Block of ELLIS ST                       |812  |
# |0 Block of STOCKTON ST                      |800  |
# |800 Block of HOWARD ST                      |795  |
# |500 Block of ELLIS ST                       |790  |
# |300 Block of TURK ST                        |776  |
# |200 Block of WINSTON DR                     |772  |
# |2700 Block of MISSION ST                    |766  |
# |0 Block of DORE ST                          |763  |
# |5TH ST / MARKET ST                          |759  |
# |200 Block of HYDE ST                        |755  |
# |0 Block of TAYLOR ST                        |752  |
# |400 Block of GEARY ST                       |751  |
# |ELLIS ST / HYDE ST                          |749  |
# |200 Block of GEARY ST                       |745  |
# |400 Block of MINNA ST                       |742  |
# |2600 Block of GEARY BL                      |731  |
# |500 Block of SOUTH VAN NESS AV              |728  |
# |800 Block of 3RD ST                         |726  |
# |0 Block of MOSS ST                          |722  |
# |3100 Block of 16TH ST                       |716  |
# |6TH ST / MISSION ST                         |710  |
# |900 Block of GEARY ST                       |708  |
# |400 Block of 6TH AV                         |707  |
# |MARKET ST / 5TH ST                          |701  |
# |0 Block of 4TH ST                           |696  |
# |500 Block of VALENCIA ST                    |696  |
# |GOLDEN GATE AV / LEAVENWORTH ST             |691  |
# |600 Block of EDDY ST                        |690  |
# |500 Block of JONES ST                       |689  |
# |100 Block of JONES ST                       |687  |
# |GOLDEN GATE AV / JONES ST                   |684  |
# |4900 Block of MISSION ST                    |679  |
# |400 Block of VALENCIA ST                    |674  |
# |1000 Block of POLK ST                       |671  |
# |2300 Block of MARKET ST                     |671  |
# |LEAVENWORTH ST / TURK ST                    |670  |
# |6TH ST / MARKET ST                          |669  |
# |900 Block of ELLSWORTH ST                   |666  |
# |300 Block of BATTERY ST                     |665  |
# |0 Block of DRUMM ST                         |654  |
# |POWELL ST / MARKET ST                       |651  |
# |400 Block of 10TH ST                        |649  |
# |0 Block of MCALLISTER ST                    |648  |
# |100 Block of STOCKTON ST                    |644  |
# |1300 Block of MARKET ST                     |640  |
# |900 Block of MISSION ST                     |635  |
# |0 Block of LEDYARD ST                       |631  |
# |EDDY ST / HYDE ST                           |629  |
# |2600 Block of MISSION ST                    |628  |
# |1200 Block of PAGE ST                       |612  |
# |LEAVENWORTH ST / GOLDEN GATE AV             |609  |
# |700 Block of VALLEJO ST                     |609  |
# |200 Block of WILLIAMS AV                    |608  |
# |OFARRELL ST / JONES ST                      |606  |
# |ELLIS ST / LEAVENWORTH ST                   |605  |
# |700 Block of HARRISON ST                    |599  |
# |300 Block of POST ST                        |598  |
# |800 Block of GEARY ST                       |596  |
# |3RD ST / PALOU AV                           |595  |
# |100 Block of LARKIN ST                      |595  |
# |500 Block of MARKET ST                      |594  |
# |300 Block of LAGUNAHONDA BL                 |589  |
# |2200 Block of MARKET ST                     |586  |
# |200 Block of KING ST                        |585  |
# |6TH ST / MINNA ST                           |578  |
# |17TH ST / SHOTWELL ST                       |578  |
# |700 Block of OFARRELL ST                    |578  |
# |500 Block of EDDY ST                        |576  |
# |800 Block of OFARRELL ST                    |574  |
# |100 Block of 4TH ST                         |571  |
# |1700 Block of HAIGHT ST                     |571  |
# |700 Block of MISSION ST                     |570  |
# |1800 Block of HAIGHT ST                     |565  |
# |1200 Block of MISSION ST                    |564  |
# |0 Block of DAKOTA ST                        |558  |
# |400 Block of RAYMOND AV                     |556  |
# |0 Block of GOLDEN GATE AV                   |552  |
# |5TH ST / MISSION ST                         |552  |
# |HAIGHT ST / STANYAN ST                      |549  |
# |1000 Block of POST ST                       |548  |
# |TURK ST / JONES ST                          |548  |
# |TURK ST / HYDE ST                           |546  |
# |500 Block of DOLORES ST                     |543  |
# |1600 Block of HAIGHT ST                     |539  |
# |2800 Block of TAYLOR ST                     |539  |
# |2300 Block of MISSION ST                    |534  |
# |500 Block of BROADWAY ST                    |534  |
# |300 Block of BAY ST                         |533  |
# |900 Block of CONNECTICUT ST                 |529  |
# |EDDY ST / TAYLOR ST                         |529  |
# |600 Block of JAMESTOWN AV                   |527  |
# |600 Block of OFARRELL ST                    |526  |
# |1000 Block of HOWARD ST                     |519  |
# |1800 Block of FOLSOM ST                     |518  |
# |1700 Block of FULTON ST                     |517  |
# |500 Block of MINNA ST                       |516  |
# |0 Block of UNITED NATIONS PZ                |513  |
# |MARKET ST / 6TH ST                          |512  |
# |0 Block of 5TH ST                           |511  |
# |400 Block of STOCKTON ST                    |510  |
# |0 Block of NORTHRIDGE RD                    |506  |
# |700 Block of ELLIS ST                       |505  |
# |GOLDEN GATE AV / HYDE ST                    |505  |
# |1500 Block of SLOAT BL                      |502  |
# |HAIGHT ST / COLE ST                         |500  |
# |800 Block of CENTRAL AV                     |499  |
# |600 Block of GEARY ST                       |498  |
# |17TH ST / MISSION ST                        |498  |
# |900 Block of HOWARD ST                      |497  |
# |500 Block of 5TH ST                         |496  |
# |500 Block of GEARY ST                       |495  |
# |1000 Block of CONNECTICUT ST                |495  |
# |1800 Block of SUNNYDALE AV                  |494  |
# |200 Block of POST ST                        |494  |
# |4700 Block of MISSION ST                    |493  |
# |1700 Block of HARRISON ST                   |491  |
# |800 Block of POTRERO AV                     |489  |
# |0 Block of BLYTHDALE AV                     |489  |
# |400 Block of POWELL ST                      |487  |
# |100 Block of CAPP ST                        |486  |
# |1000 Block of SUTTER ST                     |483  |
# |500 Block of HOWARD ST                      |483  |
# |2800 Block of MISSION ST                    |482  |
# |300 Block of 11TH ST                        |481  |
# |0 Block of JULES AV                         |480  |
# |HYDE ST / TURK ST                           |475  |
# |200 Block of 6TH ST                         |474  |
# |1000 Block of HYDE ST                       |472  |
# |700 Block of HOWARD ST                      |471  |
# |2100 Block of 24TH AV                       |471  |
# |2400 Block of SAN BRUNO AV                  |471  |
# |3100 Block of MISSION ST                    |469  |
# |100 Block of DAKOTA ST                      |469  |
# |6TH ST / JESSIE ST                          |468  |
# |300 Block of HYDE ST                        |465  |
# |19TH ST / SHOTWELL ST                       |463  |
# |400 Block of STEVENSON ST                   |462  |
# |0 Block of BROOKDALE AV                     |461  |
# |300 Block of GOLDEN GATE AV                 |461  |
# |1400 Block of MARKET ST                     |460  |
# |600 Block of MISSION ST                     |460  |
# |1700 Block of MARKET ST                     |460  |
# |0 Block of CAMERON WY                       |458  |
# |500 Block of 9TH ST                         |456  |
# |4100 Block of 18TH ST                       |456  |
# |100 Block of BLYTHDALE AV                   |456  |
# |0 Block of THE EMBARCADEROSOUTH ST          |455  |
# |0 Block of NICHOLS WY                       |455  |
# |MISSION ST / 24TH ST                        |454  |
# |MISSION ST / 6TH ST                         |452  |
# |1400 Block of HAIGHT ST                     |451  |
# |700 Block of GEARY ST                       |449  |
# |18TH ST / CASTRO ST                         |445  |
# |3RD ST / NEWCOMB AV                         |441  |
# |2100 Block of MARKET ST                     |438  |
# |500 Block of CASTRO ST                      |438  |
# |2300 Block of 24TH AV                       |438  |
# |MISSION ST / 17TH ST                        |438  |
# |900 Block of HYDE ST                        |438  |
# |1100 Block of HOWARD ST                     |437  |
# |0 Block of 12TH ST                          |436  |
# |1500 Block of HAIGHT ST                     |435  |
# |4TH ST / MISSION ST                         |435  |
# |LARKIN ST / OFARRELL ST                     |434  |
# |100 Block of WESTPOINT RD                   |430  |
# |16TH ST / VALENCIA ST                       |430  |
# |200 Block of SUTTER ST                      |430  |
# |600 Block of 32ND AV                        |429  |
# |300 Block of MASON ST                       |427  |
# |JONES ST / GOLDEN GATE AV                   |427  |
# |100 Block of 3RD ST                         |426  |
# |POST ST / LARKIN ST                         |425  |
# |100 Block of KISKA RD                       |424  |
# |1000 Block of FOLSOM ST                     |423  |
# |200 Block of 9TH ST                         |423  |
# |GEARY BL / LAGUNA ST                        |420  |
# |MARKET ST / POWELL ST                       |419  |
# |16TH ST / POTRERO AV                        |418  |
# |2500 Block of MISSION ST                    |416  |
# |1600 Block of MARKET ST                     |416  |
# |1200 Block of POLK ST                       |415  |
# |1500 Block of MARKET ST                     |414  |
# |1100 Block of MISSION ST                    |413  |
# |0 Block of 3RD ST                           |409  |
# |1800 Block of VICENTE ST                    |407  |
# |OFARRELL ST / LARKIN ST                     |406  |
# |16TH ST / SHOTWELL ST                       |405  |
# |1500 Block of VANNESS AV                    |402  |
# |8TH ST / MARKET ST                          |400  |
# |1200 Block of HOWARD ST                     |400  |
# |200 Block of POWELL ST                      |398  |
# |1700 Block of MISSION ST                    |397  |
# |EDDY ST / MASON ST                          |395  |
# |600 Block of MARKET ST                      |395  |
# |1500 Block of EDDY ST                       |395  |
# |4600 Block of MISSION ST                    |394  |
# |0 Block of 7TH ST                           |394  |
# |700 Block of KEARNY ST                      |393  |
# |100 Block of ELLIS ST                       |393  |
# |1000 Block of BUSH ST                       |393  |
# |2300 Block of FOLSOM ST                     |392  |
# |0 Block of NEWMONTGOMERY ST                 |389  |
# |MARKET ST / 4TH ST                          |387  |
# |LEAVENWORTH ST / ELLIS ST                   |385  |
# |BROADWAY ST / COLUMBUS AV                   |385  |
# |800 Block of LA PLAYA ST                    |383  |
# |200 Block of JONES ST                       |382  |
# |20TH ST / CAPP ST                           |381  |
# |3500 Block of CESAR CHAVEZ ST               |381  |
# |1100 Block of FOLSOM ST                     |379  |
# |0 Block of KEZAR DR                         |375  |
# |400 Block of POST ST                        |373  |
# |MARKET ST / 8TH ST                          |373  |
# |1600 Block of MISSION ST                    |372  |
# |SUTTER ST / LARKIN ST                       |371  |
# |1500 Block of MISSION ST                    |368  |
# |0 Block of HAROLD AV                        |368  |
# |1700 Block of SUNNYDALE AV                  |367  |
# |HAIGHT ST / MASONIC AV                      |366  |
# |500 Block of HYDE ST                        |366  |
# |1300 Block of BUSH ST                       |366  |
# |500 Block of JOHN F KENNEDY DR              |365  |
# |3800 Block of 3RD ST                        |362  |
# |200 Block of MCALLISTER ST                  |361  |
# |300 Block of COLUMBUS AV                    |361  |
# |MARKET ST / JONES ST                        |361  |
# |GEARY BL / WEBSTER ST                       |358  |
# |TAYLOR ST / TURK ST                         |357  |
# |300 Block of WILLIAMS AV                    |357  |
# |2400 Block of MISSION ST                    |355  |
# |0 Block of MARINA BL                        |354  |
# |HYDE ST / EDDY ST                           |353  |
# |400 Block of MASON ST                       |353  |
# |0 Block of 9TH ST                           |352  |
# |GENEVA AV / MISSION ST                      |351  |
# |400 Block of HAIGHT ST                      |350  |
# |JONES ST / ELLIS ST                         |347  |
# |3100 Block of FILLMORE ST                   |347  |
# |EDDY ST / LEAVENWORTH ST                    |346  |
# |300 Block of BAY SHORE BL                   |343  |
# |1000 Block of VANNESS AV                    |343  |
# |400 Block of JESSIE ST                      |343  |
# |1800 Block of 25TH ST                       |343  |
# |MISSION ST / 5TH ST                         |341  |
# |HYDE ST / GOLDEN GATE AV                    |341  |
# |GEARY ST / POWELL ST                        |340  |
# |700 Block of POLK ST                        |340  |
# |1000 Block of OAKDALE AV                    |339  |
# |800 Block of VALENCIA ST                    |339  |
# |1600 Block of MCKINNON AV                   |339  |
# |200 Block of 8TH ST                         |337  |
# |700 Block of MISSOURI ST                    |336  |
# |800 Block of FOLSOM ST                      |336  |
# |100 Block of MASON ST                       |333  |
# |500 Block of HAIGHT ST                      |333  |
# |3200 Block of MISSION ST                    |333  |
# |HYDE ST / ELLIS ST                          |332  |
# |0 Block of 5THSTNORTH ST                    |332  |
# |100 Block of POST ST                        |330  |
# |TURK ST / MASON ST                          |329  |
# |0 Block of FARALLONES ST                    |329  |
# |1400 Block of THOMAS AV                     |329  |
# |2900 Block of 16TH ST                       |329  |
# |3600 Block of LYON ST                       |328  |
# |600 Block of NATOMA ST                      |328  |
# |0 Block of SHRADER ST                       |327  |
# |400 Block of SUTTER ST                      |325  |
# |400 Block of 7TH ST                         |325  |
# |600 Block of SUTTER ST                      |324  |
# |700 Block of PACIFIC AV                     |324  |
# |0 Block of HARBOR RD                        |324  |
# |700 Block of POST ST                        |323  |
# |800 Block of PACIFIC AV                     |323  |
# |200 Block of BLYTHDALE AV                   |322  |
# |MISSION ST / 4TH ST                         |320  |
# |200 Block of 7TH ST                         |318  |
# |300 Block of GEARY ST                       |318  |
# |1000 Block of POINTLOBOS AV                 |318  |
# |100 Block of MCALLISTER ST                  |318  |
# |MISSION ST / 8TH ST                         |317  |
# |4000 Block of 18TH ST                       |317  |
# |SHOTWELL ST / 17TH ST                       |316  |
# |1100 Block of PALOU AV                      |316  |
# |200 Block of I-80                           |316  |
# |200 Block of JEFFERSON ST                   |316  |
# |HYDE ST / OFARRELL ST                       |316  |
# |600 Block of LARCH ST                       |315  |
# |MISSION ST / GENEVA AV                      |315  |
# |MISSION ST / 7TH ST                         |314  |
# |500 Block of 4TH ST                         |313  |
# |800 Block of POST ST                        |312  |
# |100 Block of JEFFERSON ST                   |312  |
# |CASTRO ST / MARKET ST                       |312  |
# |6TH ST / HOWARD ST                          |311  |
# |100 Block of GROVE ST                       |311  |
# |300 Block of CLEMENTINA ST                  |311  |
# |1200 Block of EDDY ST                       |309  |
# |1300 Block of REVERE AV                     |309  |
# |JONES ST / TURK ST                          |309  |
# |900 Block of POST ST                        |309  |
# |1500 Block of BAY SHORE BL                  |308  |
# |1900 Block of SUNNYDALE AV                  |308  |
# |300 Block of JEFFERSON ST                   |308  |
# |300 Block of 9TH ST                         |307  |
# |6TH ST / STEVENSON ST                       |306  |
# |400 Block of LEAVENWORTH ST                 |306  |
# |0 Block of MARKET ST                        |305  |
# |600 Block of POST ST                        |304  |
# |700 Block of KIRKWOOD AV                    |303  |
# |200 Block of OFARRELL ST                    |301  |
# |EDDY ST / LARKIN ST                         |300  |
# |200 Block of MASON ST                       |299  |
# |0 Block of CASTRO ST                        |299  |
# |5TH ST / HARRISON ST                        |299  |
# |2400 Block of GEARY BL                      |299  |
# |1100 Block of POTRERO AV                    |298  |
# |0 Block of SGTJOHNVYOUNG LN                 |297  |
# |300 Block of SUTTER ST                      |297  |
# |1300 Block of MISSION ST                    |296  |
# |100 Block of 7TH ST                         |296  |
# |17TH ST / CAPP ST                           |296  |
# |1200 Block of SOUTH VAN NESS AV             |296  |
# |900 Block of FOLSOM ST                      |294  |
# |2200 Block of 14TH AV                       |294  |
# |OFARRELL ST / HYDE ST                       |293  |
# |POLK ST / POST ST                           |292  |
# |100 Block of BELVEDERE ST                   |292  |
# |GEARY BL / FILLMORE ST                      |292  |
# |9TH ST / MISSION ST                         |291  |
# |1800 Block of WALLER ST                     |290  |
# |0 Block of SOUTH VAN NESS AV                |289  |
# |500 Block of LEAVENWORTH ST                 |289  |
# |1100 Block of TURK ST                       |288  |
# |0 Block of GRANT AV                         |287  |
# |0 Block of GOUGH ST                         |287  |
# |0 Block of OSCEOLA LN                       |286  |
# |100 Block of CAMERON WY                     |286  |
# |0 Block of CASHMERE ST                      |286  |
# |MISSION ST / SILVER AV                      |286  |
# |MARKET ST / TAYLOR ST                       |285  |
# |HEMLOCK ST / LARKIN ST                      |285  |
# |CAPP ST / 17TH ST                           |284  |
# |1600 Block of SUNNYDALE AV                  |284  |
# |1400 Block of PINE ST                       |284  |
# |100 Block of JOHNFKENNEDY DR                |283  |
# |1000 Block of HARRISON ST                   |283  |
# |400 Block of HYDE ST                        |282  |
# |1700 Block of CESAR CHAVEZ ST               |282  |
# |4500 Block of MISSION ST                    |281  |
# |3700 Block of 18TH ST                       |280  |
# |200 Block of 3RD ST                         |280  |
# |HAIGHT ST / SHRADER ST                      |279  |
# |1000 Block of FITZGERALD AV                 |278  |
# |0 Block of HOFF ST                          |277  |
# |5100 Block of MISSION ST                    |277  |
# |MARKET ST / VANNESS AV                      |276  |
# |EDDY ST / JONES ST                          |276  |
# |1800 Block of MISSION ST                    |274  |
# |100 Block of FONT BL                        |274  |
# |POLK ST / SUTTER ST                         |273  |
# |BROADWAY ST / KEARNY ST                     |272  |
# |TAYLOR ST / EDDY ST                         |272  |
# |400 Block of STANYAN ST                     |272  |
# |MARKET ST / MASON ST                        |271  |
# |1800 Block of OCEAN AV                      |271  |
# |JONES ST / OFARRELL ST                      |271  |
# |SUTTER ST / STOCKTON ST                     |270  |
# |800 Block of CAPP ST                        |269  |
# |1900 Block of UNION ST                      |269  |
# |400 Block of CHURCH ST                      |268  |
# |STOCKTON ST / SUTTER ST                     |268  |
# |800 Block of HARRISON ST                    |268  |
# |1100 Block of SUTTER ST                     |268  |
# |8TH ST / MISSION ST                         |268  |
# |1500 Block of SUNNYDALE AV                  |267  |
# |GEARY ST / LARKIN ST                        |267  |
# |4TH ST / MARKET ST                          |267  |
# |1600 Block of NEWCOMB AV                    |266  |
# |500 Block of POST ST                        |265  |
# |1700 Block of NEWCOMB AV                    |265  |
# |3100 Block of 24TH ST                       |265  |
# |1000 Block of GEARY ST                      |265  |
# |500 Block of SUTTER ST                      |264  |
# |MISSION ST / 18TH ST                        |264  |
# |MASON ST / TURK ST                          |261  |
# |0 Block of FELL ST                          |261  |
# |800 Block of SUTTER ST                      |261  |
# |1500 Block of FILLMORE ST                   |261  |
# |500 Block of CAPP ST                        |260  |
# |POWELL ST / GEARY ST                        |260  |
# |300 Block of VALENCIA ST                    |260  |
# |100 Block of VALENCIA ST                    |259  |
# |1100 Block of OAKDALE AV                    |259  |
# |1500 Block of POLK ST                       |259  |
# |1100 Block of FRANCISCO ST                  |258  |
# |5200 Block of DIAMONDHEIGHTS BL             |257  |
# |POLK ST / CALIFORNIA ST                     |257  |
# |100 Block of 2ND ST                         |257  |
# |7TH ST / MISSION ST                         |257  |
# |HAIGHT ST / ASHBURY ST                      |256  |
# |JONES ST / MCALLISTER ST                    |256  |
# |2500 Block of VANNESS AV                    |255  |
# |800 Block of BRANNAN ST                     |255  |
# |1200 Block of IRVING ST                     |254  |
# |1700 Block of CALIFORNIA ST                 |254  |
# |900 Block of SUTTER ST                      |254  |
# |1000 Block of CAYUGA AV                     |253  |
# |0 Block of 8TH ST                           |253  |
# |1600 Block of PALOU AV                      |253  |
# |2000 Block of CHESTNUT ST                   |252  |
# |500 Block of BRANNAN ST                     |252  |
# |LARKIN ST / SUTTER ST                       |251  |
# |GEARY BL / STEINER ST                       |251  |
# |100 Block of 9TH ST                         |251  |
# |100 Block of HIGHLAND AV                    |250  |
# |3200 Block of PIERCE ST                     |250  |
# |1700 Block of LASALLE AV                    |249  |
# |2100 Block of CHESTNUT ST                   |248  |
# |100 Block of BROOKDALE AV                   |248  |
# |100 Block of APTOS AV                       |248  |
# |FILLMORE ST / GEARY BL                      |247  |
# |500 Block of STEVENSON ST                   |247  |
# |16TH ST / CAPP ST                           |246  |
# |10TH ST / HARRISON ST                       |246  |
# |300 Block of BEACH ST                       |245  |
# |1100 Block of SCOTT ST                      |245  |
# |100 Block of JULIAN AV                      |244  |
# |300 Block of STOCKTON ST                    |244  |
# |0 Block of JEFFERSON ST                     |243  |
# |1200 Block of VANNESS AV                    |243  |
# |400 Block of BRANNAN ST                     |242  |
# |1600 Block of THE EMBARCADERO NORTH ST      |242  |
# |600 Block of HYDE ST                        |241  |
# |900 Block of MASON ST                       |240  |
# |4400 Block of MISSION ST                    |240  |
# |600 Block of MINNA ST                       |239  |
# |700 Block of NATOMA ST                      |238  |
# |400 Block of ARGUELLO BL                    |238  |
# |500 Block of MISSION ST                     |238  |
# |LARKIN ST / GROVE ST                        |238  |
# |900 Block of NORTHPOINT ST                  |237  |
# |800 Block of CAPITOL AV                     |237  |
# |800 Block of ELLSWORTH ST                   |237  |
# |MINNA ST / 6TH ST                           |237  |
# |200 Block of VALENCIA ST                    |237  |
# |100 Block of NEWMONTGOMERY ST               |237  |
# |3400 Block of MISSION ST                    |236  |
# |HARRISON ST / 4TH ST                        |236  |
# |1600 Block of BRYANT ST                     |236  |
# |2300 Block of BUCHANAN ST                   |236  |
# |MISSION ST / 30TH ST                        |235  |
# |800 Block of ELLIS ST                       |235  |
# |500 Block of BEACH ST                       |235  |
# |500 Block of HOLLOWAY AV                    |234  |
# |CHURCH ST / MARKET ST                       |234  |
# |3RD ST / EVANS AV                           |233  |
# |1200 Block of TURK ST                       |233  |
# |2800 Block of LEAVENWORTH ST                |233  |
# |1100 Block of FITZGERALD AV                 |233  |
# |100 Block of FELL ST                        |233  |
# |18TH ST / MISSION ST                        |233  |
# |2000 Block of UNION ST                      |233  |
# |1200 Block of REVERE AV                     |232  |
# |1600 Block of KIRKWOOD AV                   |232  |
# |400 Block of MANSELL ST                     |232  |
# |1100 Block of POLK ST                       |231  |
# |200 Block of CAPP ST                        |231  |
# |3900 Block of ALEMANY BL                    |231  |
# |800 Block of CHINABASIN ST                  |230  |
# |VANNESS AV / MARKET ST                      |230  |
# |0 Block of LEAVENWORTH ST                   |230  |
# |0 Block of GEARY ST                         |230  |
# |0 Block of PERRY ST                         |229  |
# |300 Block of 5TH ST                         |229  |
# |GEARY ST / HYDE ST                          |228  |
# |500 Block of CALIFORNIA ST                  |228  |
# |1000 Block of GREAT HY                      |227  |
# |500 Block of JOHNMUIR DR                    |227  |
# |1100 Block of BUSH ST                       |227  |
# |100 Block of CALIFORNIA ST                  |227  |
# |JONES ST / MARKET ST                        |226  |
# |200 Block of MARKET ST                      |225  |
# |700 Block of FOLSOM ST                      |225  |
# |0 Block of MIDDLEPOINT RD                   |225  |
# |1800 Block of EDDY ST                       |225  |
# |400 Block of BAY ST                         |225  |
# |CALIFORNIA ST / POLK ST                     |225  |
# |1900 Block of MARKET ST                     |224  |
# |3RD ST / OAKDALE AV                         |224  |
# |3300 Block of 17TH ST                       |224  |
# |0 Block of SANTOS ST                        |224  |
# |600 Block of STANYAN ST                     |223  |
# |200 Block of GRANT AV                       |223  |
# |600 Block of VANNESS AV                     |223  |
# |5000 Block of MISSION ST                    |223  |
# |MARKET ST / CASTRO ST                       |223  |
# |400 Block of CAPP ST                        |223  |
# |4TH ST / HARRISON ST                        |222  |
# |GOLDEN GATE AV / TAYLOR ST                  |222  |
# |3000 Block of 24TH ST                       |221  |
# |2500 Block of SUTTER ST                     |221  |
# |MISSION ST / PERSIA AV                      |221  |
# |500 Block of JESSIE ST                      |221  |
# |500 Block of PORTOLA DR                     |221  |
# |0 Block of WATCHMAN WY                      |220  |
# |300 Block of ARBALLO DR                     |220  |
# |500 Block of ALEMANY BL                     |219  |
# |700 Block of JERROLD AV                     |219  |
# |1400 Block of FILLMORE ST                   |218  |
# |200 Block of ONEIDA AV                      |218  |
# |HAIGHT ST / CLAYTON ST                      |218  |
# |1500 Block of BRYANT ST                     |218  |
# |2000 Block of POLK ST                       |218  |
# |LEAVENWORTH ST / EDDY ST                    |218  |
# |MISSION ST / 20TH ST                        |218  |
# |CASTRO ST / 18TH ST                         |218  |
# |600 Block of BROADWAY ST                    |218  |
# |4800 Block of MISSION ST                    |217  |
# |700 Block of LARKIN ST                      |217  |
# |200 Block of HAIGHT ST                      |217  |
# |100 Block of CHURCH ST                      |217  |
# |11TH ST / FOLSOM ST                         |216  |
# |3RD ST / HARRISON ST                        |216  |
# |600 Block of FOLSOM ST                      |216  |
# |0 Block of CHUMASERO DR                     |216  |
# |11TH ST / HARRISON ST                       |216  |
# |3RD ST / HOWARD ST                          |216  |
# |400 Block of DUBOCE AV                      |215  |
# |16TH ST / BRYANT ST                         |215  |
# |STEVENSON ST / 6TH ST                       |215  |
# |2500 Block of LOMBARD ST                    |215  |
# |6TH ST / HARRISON ST                        |215  |
# |6TH ST / FOLSOM ST                          |214  |
# |3900 Block of 18TH ST                       |214  |
# |400 Block of 6TH ST                         |213  |
# |200 Block of TAYLOR ST                      |213  |
# |100 Block of OTIS ST                        |213  |
# |HARRISON ST / 5TH ST                        |213  |
# |600 Block of JONES ST                       |213  |
# |900 Block of GENEVA AV                      |213  |
# |0 Block of CONKLING ST                      |213  |
# |600 Block of LARKIN ST                      |213  |
# |300 Block of 4TH ST                         |212  |
# |MARKET ST / 3RD ST                          |212  |
# |3200 Block of 24TH ST                       |211  |
# |1300 Block of VANNESS AV                    |211  |
# |1600 Block of FOLSOM ST                     |211  |
# |300 Block of TAYLOR ST                      |210  |
# |2900 Block of MISSION ST                    |210  |
# |2800 Block of 24TH ST                       |210  |
# |MARKET ST / CHURCH ST                       |210  |
# |200 Block of WESTPOINT RD                   |210  |
# |9TH ST / HOWARD ST                          |210  |
# |6200 Block of 3RD ST                        |210  |
# |900 Block of VALENCIA ST                    |209  |
# |1300 Block of STOCKTON ST                   |209  |
# |0 Block of MONTGOMERY ST                    |209  |
# |1300 Block of COLUMBUS AV                   |209  |
# |700 Block of 7TH AV                         |208  |
# |3500 Block of FILLMORE ST                   |208  |
# |200 Block of 13TH ST                        |208  |
# |200 Block of ELLIS ST                       |208  |
# |18TH ST / FOLSOM ST                         |208  |
# |100 Block of JACKSON ST                     |207  |
# |200 Block of BAY SHORE BL                   |207  |
# |700 Block of EDDY ST                        |207  |
# |400 Block of MARKET ST                      |206  |
# |400 Block of NATOMA ST                      |206  |
# |600 Block of CLAY ST                        |206  |
# |2700 Block of SAN BRUNO AV                  |206  |
# |ELLIS ST / TAYLOR ST                        |206  |
# |0 Block of WOODWARD ST                      |205  |
# |3RD ST / LASALLE AV                         |205  |
# |19TH AV / WINSTON DR                        |205  |
# |100 Block of 12TH ST                        |205  |
# |500 Block of NATOMA ST                      |205  |
# |4500 Block of 3RD ST                        |204  |
# |0 Block of BERTHA LN                        |204  |
# |GROVE ST / LARKIN ST                        |203  |
# |MISSION ST / 19TH ST                        |203  |
# |1700 Block of QUESADA AV                    |203  |
# |3RD ST / REVERE AV                          |203  |
# |1000 Block of PALOU AV                      |203  |
# |HAIGHT ST / FILLMORE ST                     |203  |
# |GEARY BL / GOUGH ST                         |202  |
# |600 Block of BUSH ST                        |202  |
# |GEARY ST / LEAVENWORTH ST                   |202  |
# |200 Block of COLUMBUS AV                    |202  |
# |200 Block of 2ND ST                         |202  |
# |0 Block of LOBOS ST                         |202  |
# |1000 Block of GILMAN AV                     |201  |
# |300 Block of HAIGHT ST                      |201  |
# |BUSH ST / POLK ST                           |201  |
# |2700 Block of 16TH ST                       |201  |
# |800 Block of EDDY ST                        |200  |
# |1400 Block of POLK ST                       |200  |
# |JESSIE ST / 6TH ST                          |200  |
# |1200 Block of NEWHALL ST                    |199  |
# |600 Block of HOWARD ST                      |199  |
# |1500 Block of CALIFORNIA ST                 |199  |
# |1000 Block of SOUTH VAN NESS AV             |199  |
# |4800 Block of 3RD ST                        |199  |
# |400 Block of GENEVA AV                      |199  |
# |800 Block of SOUTH VAN NESS AV              |199  |
# |BAY ST / KEARNY ST                          |199  |
# |700 Block of SUTTER ST                      |199  |
# |700 Block of GOLDEN GATE AV                 |198  |
# |0 Block of CORTLAND AV                      |198  |
# |500 Block of LARKIN ST                      |196  |
# |300 Block of GRANT AV                       |196  |
# |LARKIN ST / EDDY ST                         |196  |
# |POLK ST / GEARY ST                          |196  |
# |800 Block of LARKIN ST                      |196  |
# |300 Block of FULTON ST                      |196  |
# |GEARY ST / POLK ST                          |196  |
# |ELLIS ST / LARKIN ST                        |196  |
# |NEWCOMB AV / 3RD ST                         |195  |
# |19TH ST / MISSION ST                        |195  |
# |800 Block of BUSH ST                        |195  |
# |200 Block of DOLORES ST                     |195  |
# |400 Block of 30TH AV                        |195  |
# |17TH ST / SOUTH VAN NESS AV                 |194  |
# |POST ST / POLK ST                           |194  |
# |STANYAN ST / HAIGHT ST                      |194  |
# |800 Block of TURK ST                        |194  |
# |PALOU AV / 3RD ST                           |194  |
# |1400 Block of 7TH AV                        |193  |
# |22ND ST / MISSION ST                        |193  |
# |100 Block of TOWNSEND ST                    |193  |
# |3RD ST / MARKET ST                          |193  |
# |3RD ST / WILLIAMS AV                        |193  |
# |SAN JOSE AV / RANDALL ST                    |192  |
# |MISSION ST / 23RD ST                        |192  |
# |POLK ST / PINE ST                           |191  |
# |17TH ST / VALENCIA ST                       |191  |
# |3RD ST / MISSION ST                         |191  |
# |1300 Block of POLK ST                       |191  |
# |200 Block of 10TH ST                        |191  |
# |1300 Block of CALIFORNIA ST                 |190  |
# |1200 Block of STOCKTON ST                   |190  |
# |1500 Block of SHAFTER AV                    |190  |
# |1300 Block of HAIGHT ST                     |190  |
# |4TH ST / KING ST                            |190  |
# |1700 Block of MCKINNON AV                   |190  |
# |CHURCH ST / DUBOCE AV                       |189  |
# |100 Block of SUTTER ST                      |189  |
# |200 Block of BRANNAN ST                     |189  |
# |700 Block of TAYLOR ST                      |189  |
# |500 Block of BRYANT ST                      |189  |
# |LARKIN ST / POST ST                         |188  |
# |0 Block of POST ST                          |188  |
# |1300 Block of GILMAN AV                     |188  |
# |1400 Block of CALIFORNIA ST                 |188  |
# |LEAVENWORTH ST / MCALLISTER ST              |187  |
# |500 Block of GREEN ST                       |187  |
# |1400 Block of SHAFTER AV                    |187  |
# |300 Block of SACRAMENTO ST                  |187  |
# |300 Block of 2ND ST                         |186  |
# |LARKIN ST / GEARY ST                        |186  |
# |COLUMBUS AV / BROADWAY ST                   |186  |
# |200 Block of STOCKTON ST                    |186  |
# |400 Block of MISSION ST                     |186  |
# |3RD ST / QUESADA AV                         |186  |
# |4100 Block of GEARY BL                      |185  |
# |900 Block of BUSH ST                        |185  |
# |1600 Block of TURK ST                       |185  |
# |20TH ST / MISSION ST                        |185  |
# |2100 Block of POWELL ST                     |185  |
# |100 Block of GEARY ST                       |185  |
# |100 Block of STEUART ST                     |185  |
# |SAN BRUNO AV / SILVER AV                    |185  |
# |0 Block of WESTPOINT RD                     |185  |
# |MISSION ST / 9TH ST                         |185  |
# |100 Block of GUERRERO ST                    |185  |
# |500 Block of HAYES ST                       |185  |
# |200 Block of GUERRERO ST                    |184  |
# |6600 Block of 3RD ST                        |184  |
# |1300 Block of FILLMORE ST                   |184  |
# |16TH ST / SOUTH VAN NESS AV                 |184  |
# |1000 Block of LARKIN ST                     |184  |
# |2100 Block of UNION ST                      |184  |
# |1500 Block of REVERE AV                     |183  |
# |500 Block of 3RD ST                         |183  |
# |1700 Block of EDDY ST                       |183  |
# |GEARY ST / JONES ST                         |183  |
# |0 Block of CALIFORNIA ST                    |183  |
# |0 Block of TOWNSEND ST                      |183  |
# |1800 Block of MARKET ST                     |183  |
# |300 Block of SPEAR ST                       |183  |
# |8TH ST / FOLSOM ST                          |183  |
# |9TH ST / MARKET ST                          |182  |
# |2200 Block of CHESTNUT ST                   |182  |
# |1800 Block of UNION ST                      |182  |
# |600 Block of POLK ST                        |182  |
# |0 Block of LELAND AV                        |182  |
# |1700 Block of OAKDALE AV                    |182  |
# |3000 Block of MISSION ST                    |182  |
# |1100 Block of VALENCIA ST                   |182  |
# |0 Block of GARLINGTON CT                    |181  |
# |2000 Block of FILLMORE ST                   |181  |
# |GENEVA AV / SAN JOSE AV                     |181  |
# |MISSION ST / 14TH ST                        |181  |
# |100 Block of LELAND AV                      |180  |
# |600 Block of COLUMBUS AV                    |180  |
# |CESAR CHAVEZ ST / VERMONT ST                |180  |
# |1700 Block of MCALLISTER ST                 |180  |
# |1600 Block of POST ST                       |180  |
# |200 Block of HARBOR RD                      |180  |
# |400 Block of DAVIS CT                       |180  |
# |300 Block of CAPP ST                        |179  |
# |100 Block of SPEAR ST                       |179  |
# |2200 Block of VANNESS AV                    |179  |
# |100 Block of PERSIA AV                      |179  |
# |6TH ST / NATOMA ST                          |179  |
# |2400 Block of HARRISON ST                   |179  |
# |OFARRELL ST / LEAVENWORTH ST                |178  |
# |700 Block of BUSH ST                        |178  |
# |POLK ST / BUSH ST                           |178  |
# |CAPP ST / 16TH ST                           |178  |
# |4700 Block of 3RD ST                        |178  |
# |5TH ST / HOWARD ST                          |178  |
# |700 Block of MINNA ST                       |178  |
# |1500 Block of FOLSOM ST                     |178  |
# |500 Block of FRANCISCO ST                   |178  |
# |300 Block of THE EMBARCADERONORTH ST        |178  |
# |MISSION ST / 22ND ST                        |178  |
# |200 Block of 11TH ST                        |177  |
# |1700 Block of POST ST                       |177  |
# |200 Block of CALIFORNIA ST                  |177  |
# |1100 Block of EUCALYPTUS DR                 |177  |
# |LEAVENWORTH ST / OFARRELL ST                |176  |
# |3300 Block of 23RD ST                       |176  |
# |1700 Block of LOMBARD ST                    |176  |
# |2400 Block of GRIFFITH ST                   |176  |
# |0 Block of SANCHEZ ST                       |176  |
# |SUNNYDALE AV / HAHN ST                      |176  |
# |2400 Block of MARKET ST                     |176  |
# |VANNESS AV / MCALLISTER ST                  |176  |
# |3RD ST / MCKINNON AV                        |176  |
# |500 Block of COLUMBUS AV                    |175  |
# |GEARY ST / STOCKTON ST                      |175  |
# |2ND ST / TOWNSEND ST                        |175  |
# |SILVER AV / SAN BRUNO AV                    |175  |
# |CEDAR ST / POLK ST                          |175  |
# |HYDE ST / MCALLISTER ST                     |175  |
# |3200 Block of 26TH ST                       |175  |
# |1000 Block of VALENCIA ST                   |174  |
# |5TH ST / FOLSOM ST                          |174  |
# |1300 Block of GRANT AV                      |174  |
# |TURK ST / LARKIN ST                         |174  |
# |3900 Block of 24TH ST                       |174  |
# |600 Block of MONTEREY BL                    |173  |
# |1400 Block of BUSH ST                       |173  |
# |100 Block of APPLETON AV                    |173  |
# |VALENCIA ST / 16TH ST                       |173  |
# |600 Block of HARRISON ST                    |173  |
# |19TH AV / HOLLOWAY AV                       |173  |
# |STOCKTON ST / BROADWAY ST                   |173  |
# |EDDY ST / POLK ST                           |172  |
# |500 Block of DIVISADERO ST                  |172  |
# |OFARRELL ST / POWELL ST                     |172  |
# |30TH ST / MISSION ST                        |172  |
# |14TH ST / MISSION ST                        |172  |
# |400 Block of COLUMBUS AV                    |172  |
# |0 Block of ELLIS ST                         |172  |
# |3800 Block of 18TH ST                       |172  |
# |100 Block of 8TH ST                         |172  |
# |3RD ST / KING ST                            |171  |
# |200 Block of CHURCH ST                      |171  |
# |1600 Block of OAKDALE AV                    |170  |
# |2000 Block of LOMBARD ST                    |170  |
# |200 Block of KEARNY ST                      |170  |
# |18TH ST / SHOTWELL ST                       |170  |
# |1100 Block of GOUGH ST                      |170  |
# |1000 Block of GRIFFITH ST                   |170  |
# |100 Block of CAMBON DR                      |170  |
# |EDDY ST / BUCHANAN ST                       |169  |
# |MISSION ST / SYCAMORE ST                    |169  |
# |3300 Block of 24TH ST                       |169  |
# |KEITH ST / THOMAS AV                        |169  |
# |900 Block of HARRISON ST                    |168  |
# |POWELL ST / OFARRELL ST                     |168  |
# |1000 Block of HOLLISTER AV                  |168  |
# |MISSION ST / SOUTH VAN NESS AV              |168  |
# |2500 Block of SAN BRUNO AV                  |168  |
# |TAYLOR ST / ELLIS ST                        |168  |
# |600 Block of CALIFORNIA ST                  |168  |
# |700 Block of TARAVAL ST                     |168  |
# |2100 Block of LOMBARD ST                    |168  |
# |1100 Block of LARKIN ST                     |167  |
# |0 Block of DEDMAN CT                        |167  |
# |SHOTWELL ST / 19TH ST                       |167  |
# |0 Block of LATONA ST                        |167  |
# |MISSION ST / 15TH ST                        |166  |
# |1500 Block of QUESADA AV                    |166  |
# |MARKET ST / 10TH ST                         |166  |
# |500 Block of SHOTWELL ST                    |166  |
# |CAPP ST / 20TH ST                           |166  |
# |MARKET ST / 9TH ST                          |165  |
# |HYDE ST / FULTON ST                         |165  |
# |700 Block of BAKER ST                       |165  |
# |600 Block of DEHARO ST                      |165  |
# |1100 Block of POST ST                       |165  |
# |0 Block of TURNER TR                        |165  |
# |4TH ST / HOWARD ST                          |165  |
# |HAIGHT ST / WEBSTER ST                      |165  |
# |3100 Block of 26TH ST                       |165  |
# |100 Block of MARKET ST                      |164  |
# |500 Block of BUENAVISTAWEST AV              |164  |
# |300 Block of GIRARD ST                      |163  |
# |GOLDEN GATE AV / LARKIN ST                  |163  |
# |2000 Block of BROADWAY ST                   |163  |
# |1600 Block of QUESADA AV                    |163  |
# |FILLMORE ST / OFARRELL ST                   |163  |
# |23RD ST / MISSION ST                        |163  |
# |1300 Block of PINE ST                       |162  |
# |100 Block of BRITTON ST                     |162  |
# |POLK ST / EDDY ST                           |162  |
# |1500 Block of HOWARD ST                     |162  |
# |10TH ST / BRYANT ST                         |161  |
# |300 Block of 7TH ST                         |161  |
# |800 Block of VANNESS AV                     |161  |
# |16TH ST / HOFF ST                           |161  |
# |1200 Block of BUSH ST                       |161  |
# |1500 Block of OAKDALE AV                    |161  |
# |MCALLISTER ST / LEAVENWORTH ST              |161  |
# |900 Block of COLUMBUS AV                    |160  |
# |CALIFORNIA ST / LARKIN ST                   |160  |
# |2900 Block of 24TH ST                       |160  |
# |100 Block of BAY ST                         |160  |
# |1500 Block of SUTTER ST                     |159  |
# ...
# |1500 Block of BIRCHWOOD CT                  |1    |
# |FORTUNA AV / ANZAVISTA AV                   |1    |
# |ARGUELLO BL / NORTHRIDGE DR                 |1    |
# |BYXBEE ST / RANDOLPH ST                     |1    |
# |SOLA AV / MARCELA AV                        |1    |
# |CABRILLO ST / 40TH AV                       |1    |
# |1100 Block of WAYLAND ST                    |1    |
# |TANDANG SORA ST / BONIFACIO ST              |1    |
# |POWHATTAN AV / FOLSOM ST                    |1    |
# |COLON AV / GREENWOOD AV                     |1    |
# |1000 Block of THOMAS AV                     |1    |
# |3300 Block of LAWTON ST                     |1    |
# |FOERSTER ST / JOOST AV                      |1    |
# |FOWLER AV / JUANITA WY                      |1    |
# |JONES ST / COLIN PL                         |1    |
# |EUCALYPTUS DR / 23RD AV                     |1    |
# |BLANKEN AV / EXECUTIVE PARK BL              |1    |
# |ROCKDALE DR / ISOLA WY                      |1    |
# |HATTIE ST / CORBETT AV                      |1    |
# |COLUMBIA SQUARE ST / HARRISON ST            |1    |
# |PACHECO ST / DEWEY BL                       |1    |
# |ALPHA ST / TIOGA AV                         |1    |
# |DONAHUE ST / JERROLD AV                     |1    |
# |600 Block of MARTIN LUTHER KING JR DR       |1    |
# |SELBY ST / NEWCOMB AV                       |1    |
# |0 Block of SANTA ANA AV                     |1    |
# |WHITTIER ST / BRUNSWICK ST                  |1    |
# |LEIDESDORFF ST / COMMERCIAL ST              |1    |
# |0 Block of SPRING ST                        |1    |
# |ROLPH ST / MORSE ST                         |1    |
# |MADISON ST / BURROWS ST                     |1    |
# |JONES ST / GLOVER ST                        |1    |
# |4TH ST / ELLIS ST                           |1    |
# |CRESTLAKE DR / PARAISO PL                   |1    |
# |LAPU LAPU ST / RIZAL ST                     |1    |
# |FRANK NORRIS ST / LARKIN ST                 |1    |
# |UPTON ST / MCKINNON AV                      |1    |
# |OTSEGO AV / SANTAYNEZ AV                    |1    |
# |SHRADER ST / 17TH ST                        |1    |
# |3900 Block of QUINTARA ST                   |1    |
# |COLLINS ST / ANZA ST                        |1    |
# |PORTOLA DR / SANTAPAULA AV                  |1    |
# |25TH AV / SANTIAGO ST                       |1    |
# |DETROIT ST / FLOOD AV                       |1    |
# |33RD AV / IRVING ST                         |1    |
# |SWISS AV / SURREY ST                        |1    |
# |VALLEJO ST / BRODERICK ST                   |1    |
# |DIVISADERO ST / BEACH ST                    |1    |
# |1600 Block of SILLIMAN ST                   |1    |
# |GRIFFITH ST / VAN DYKE AV                   |1    |
# |TAYLOR ST / PLEASANT ST                     |1    |
# |COTTER ST / SAN JOSE AV                     |1    |
# |LOTTIEBENNETT LN / WESTERNSHORES LN         |1    |
# |BAKER ST / TERRAVISTA AV                    |1    |
# |0 Block of LAGUNA HONDA BL                  |1    |
# |CLAY ST / THE EMBARCADERO NORTH ST          |1    |
# |CHESTNUT ST / KEARNY ST                     |1    |
# |CONSTANSO WY / SLOAT BL                     |1    |
# |MILL ST / ANKENY ST                         |1    |
# |PACHECO ST / 33RD AV                        |1    |
# |40TH AV / CLEMENT ST                        |1    |
# |MC KINNON AV / UPTON ST                     |1    |
# |100 Block of ALICE B TOKLAS PL              |1    |
# |MARKET ST / SHORT ST                        |1    |
# |GAVIOTA WY / BELLAVISTA WY                  |1    |
# |DE HARO ST / MARIPOSA ST                    |1    |
# |MOSCOW ST / EXCELSIOR AV                    |1    |
# |34TH AV / MORAGA ST                         |1    |
# |MARGRAVE PL / VALLEJO ST                    |1    |
# |WALLER ST / POTOMAC ST                      |1    |
# |VALDEZ AV / MONTEREY BL                     |1    |
# |VINTON CT / GRANT AV                        |1    |
# |500 Block of 25TH ST                        |1    |
# |MIDDLE DR / BOWLING GREEN DR                |1    |
# |100 Block of POWHATTAN AV                   |1    |
# |800 Block of 4TH AV                         |1    |
# |PANORAMA DR / OLYMPIA WY                    |1    |
# |OCEAN AV / PINEHURST WY                     |1    |
# |WAWONA ST / 35TH AV                         |1    |
# |YERBABUENA AV / BRENTWOOD AV                |1    |
# |FREELON ST / ZOE ST                         |1    |
# |WAYLAND ST / YALE ST                        |1    |
# |2ND AV / CORNWALL ST                        |1    |
# |BREWSTER ST / ESMERALDA AV                  |1    |
# |COLLEGE AV / MURRAY ST                      |1    |
# |GRANT AV / NOBLES AL                        |1    |
# |ELLINGTON AV / NAGLEE AV                    |1    |
# |THE EMBARCADERO SOUTH ST / SPEAR ST         |1    |
# |3800 Block of WEBSTER ST                    |1    |
# |MOUNT VERNON AV / GRAFTON AV                |1    |
# |SILLIMAN ST / MADISON ST                    |1    |
# |MONTEREY BL / SAN LEANDRO WY                |1    |
# |17TH ST / RHODE ISLAND ST                   |1    |
# |ROMOLO ST / VALLEJO ST                      |1    |
# |ROSEMONT PL / 14TH ST                       |1    |
# |SWEENY ST / DARTMOUTH ST                    |1    |
# |200 Block of JESSIE ST                      |1    |
# |CLAREMONT BL / PORTOLA DR                   |1    |
# |0 Block of SANTA YSABEL AV                  |1    |
# |BURR AV / MC CARTHY AV                      |1    |
# |SUSSEX ST / SWISS AV                        |1    |
# |EUCALYPTUS DR / FORESTVIEW DR               |1    |
# |MONTEREY BL / SAN ANSELMO AV                |1    |
# |ARTHUR AV / QUINT ST                        |1    |
# |SANTAYNEZ AV / DELANO AV                    |1    |
# |3000 Block of KIRKHAM ST                    |1    |
# |BOCANA ST / ELLERT ST                       |1    |
# |27TH AV / LINCOLN WY                        |1    |
# |0 Block of ISADORA DUNCAN PL                |1    |
# |DESOTO ST / HOLLOWAY AV                     |1    |
# |OCTAVIA ST / FRANCISCO ST                   |1    |
# |700 Block of HOLLY PARK CR                  |1    |
# |BROADWAY ST / NORMANDIE TR                  |1    |
# |OCEAN AV / PALOMA AV                        |1    |
# |MERCED AV / PACHECO ST                      |1    |
# |BUSH ST / 1ST ST                            |1    |
# |ANZA ST / 45TH AV                           |1    |
# |GAMBIER ST / SILLIMAN ST                    |1    |
# |WALLER ST / BUENA VISTA WEST AV             |1    |
# |SAN JOSE AV / NAGLEE AV                     |1    |
# |THOMAS AV / QUINT ST                        |1    |
# |DE HARO ST / 20TH ST                        |1    |
# |300 Block of COUNTRY CLUB DR                |1    |
# |SLOAT BL / RIVERTON DR                      |1    |
# |BANKS ST / POWHATTAN AV                     |1    |
# |0 Block of VISTA VERDE CT                   |1    |
# |1000 Block of LA PLAYA ST                   |1    |
# |CALIFORNIA ST / 29TH AV                     |1    |
# |ROMAIN ST / DOUGLASS ST                     |1    |
# |MAGELLAN AV / CORTES AV                     |1    |
# |PORTOLA DR / TERRACE DR                     |1    |
# |2ND ST / SOUTH PARK AV                      |1    |
# |CLIPPER ST / DOLORES ST                     |1    |
# |HARKNESS AV / DELTA ST                      |1    |
# |NEWTON ST / BRUNSWICK ST                    |1    |
# |400 Block of YERBA BUENA AV                 |1    |
# |CORDOVA ST / WINDING WY                     |1    |
# |47TH AV / ANZA ST                           |1    |
# |1000 Block of HUDSON AV                     |1    |
# |18TH ST / CLOVER ST                         |1    |
# |EDGEWOOD AV / BELMONT AV                    |1    |
# |BRYANT ST / RITCH ST                        |1    |
# |LURLINE ST / KIRKHAM ST                     |1    |
# |AVILA ST / CERVANTES BL                     |1    |
# |CABRILLO ST / 19TH AV                       |1    |
# |RAMONA ST / 14TH ST                         |1    |
# |36TH AV / VICENTE ST                        |1    |
# |SPEAR ST / THE EMBARCADERO SOUTH ST         |1    |
# |PINE ST / CENTURY PL                        |1    |
# |GRAFTON AV / ORIZABA AV                     |1    |
# |ULLOA ST / 47TH AV                          |1    |
# |26TH AV / NORIEGA ST                        |1    |
# |100 Block of SANTA YSABEL AV                |1    |
# |SCOTIA AV / BRIDGEVIEW DR                   |1    |
# |LANDERS ST / ALERT AL                       |1    |
# |1900 Block of 26TH ST                       |1    |
# |KEMPTON AV / ALEMANY BL                     |1    |
# |CLAREMONT BL / KENSINGTON WY                |1    |
# |100 Block of ELK ST                         |1    |
# |100 Block of BEHR AV                        |1    |
# |DELANO AV / SANTA YNEZ AV                   |1    |
# |WISCONSIN ST / BLAIR TR                     |1    |
# |WALLER ST / KEZAR DR                        |1    |
# |BROADWAY ST / TURK MURPHY LN                |1    |
# |MARIST CT / INNES AV                        |1    |
# |ECKER ST / ELIM AL                          |1    |
# |SAN MIGUEL ST / MT VERNON AV                |1    |
# |BLANCHE ST / ELIZABETH ST                   |1    |
# |1100 Block of ORTEGA ST                     |1    |
# |400 Block of SCHWERIN ST                    |1    |
# |FERNWOOD DR / BRENTWOOD AV                  |1    |
# |2800 Block of 15TH AV                       |1    |
# |GLENDALE ST / MARKET ST                     |1    |
# |LANSING ST / GUY PL                         |1    |
# |400 Block of SEA CLIFF AV                   |1    |
# |JULIA ST / MISSION ST                       |1    |
# |MOUNT VERNON AV / WILLIAR AV                |1    |
# |BUSH ST / BELDEN ST                         |1    |
# |LAPU LAPU ST / BONIFACIO ST                 |1    |
# |LILLIAN ST / BEATRICE LN                    |1    |
# |ROLPH ST / CURTIS ST                        |1    |
# |MAJESTIC AV / SUMMIT ST                     |1    |
# |DIAMOND ST / MORELAND ST                    |1    |
# |YUKON ST / 19TH ST                          |1    |
# |HARDING RD / SKYLINE BLVD HY                |1    |
# |CRESTA VISTA DR / COVENTRY CT               |1    |
# |NEW MONTGOMERY ST / STEVENSON ST            |1    |
# |100 Block of LAKE MERCED HILL SOU ST        |1    |
# |30TH AV / QUINTARA ST                       |1    |
# |DUNCAN ST / REDROCK WY                      |1    |
# |PAUL AV / DWIGHT ST                         |1    |
# |200 Block of HALLECK ST                     |1    |
# |UNION ST / FRONT ST                         |1    |
# |COLIN P KELLY JR ST / TOWNSEND ST           |1    |
# |DIVISADERO ST / GARDEN ST                   |1    |
# |FRESNO ST / KEARNY ST                       |1    |
# |500 Block of AMADOR ST                      |1    |
# |0 Block of RAYBURN ST                       |1    |
# |0 Block of GLENBROOK AV                     |1    |
# |GREAT HWY / LA PLAYA ST                     |1    |
# |CORBETT AV / 17TH ST                        |1    |
# |0 Block of PRESCOT CT                       |1    |
# |JOHN F KENNEDY DR / CHAIN OF LAKES DR       |1    |
# |CRESCENT AV / PERALTA AV                    |1    |
# |0 Block of STELMO WY                        |1    |
# |MIGUEL ST / LAIDLEY ST                      |1    |
# |15TH AV / WAWONA ST                         |1    |
# |0 Block of CODMAN PL                        |1    |
# |CORWIN ST / DOUGLASS ST                     |1    |
# |ALEMANY BL / REGENT ST                      |1    |
# |THE EMBARCADERO NORTH ST / BEACH ST         |1    |
# |SCOTIA AV / QUINT ST                        |1    |
# |200 Block of SAN LEANDRO WY                 |1    |
# |100 Block of VIDAL DR                       |1    |
# |43RD AV / QUINTARA ST                       |1    |
# |POPE ST / BALTIMORE WY                      |1    |
# |ALVARADO ST / SAN JOSE AV                   |1    |
# |0 Block of JULIUS ST                        |1    |
# |RIVAS AV / VIDAL DR                         |1    |
# |MARSILY ST / ST MARYS AV                    |1    |
# |25TH ST / HOFFMAN AV                        |1    |
# |FUNSTON AV / ALOHA AV                       |1    |
# |WAWONA ST / 33RD AV                         |1    |
# |THE EMBARCADERO NORTH ST / GRANT AV         |1    |
# |1700 Block of UPPER GREAT HY                |1    |
# |PACHECO ST / SUNSET BL                      |1    |
# |300 Block of 25TH ST                        |1    |
# |FRANCONIA ST / SAMOSET ST                   |1    |
# |CASELLI AV / YUKON ST                       |1    |
# |ADMIRAL AV / CAMELLIA AV                    |1    |
# |44TH AV / RIVERA ST                         |1    |
# |JAMESTOWN AV / HUNTERS PT EXPWY EX          |1    |
# |IRVING ST / 44TH AV                         |1    |
# |200 Block of PARKPRESIDIO BL                |1    |
# |WAYLAND ST / BOWDOIN ST                     |1    |
# |ELLIS ST / INCA LN                          |1    |
# |1400 Block of QUINTARA ST                   |1    |
# |DELMAR ST / PIEDMONT ST                     |1    |
# |400 Block of SKYLINEBLVD HY                 |1    |
# |1100 Block of WALLER ST                     |1    |
# |ANZAVISTA AV / BAKER ST                     |1    |
# |MULLEN AV / RUTLEDGE ST                     |1    |
# |RIVERA ST / 20TH AV                         |1    |
# |SCOTT ST / BROADWAY ST                      |1    |
# |APPLETON AV / GLADYS ST                     |1    |
# |MONTGOMERY ST / THE EMBARCADERONORTH ST     |1    |
# |18TH ST / STORRIE ST                        |1    |
# |GRANDVIEW AV / ALVARADO ST                  |1    |
# |32ND AV / FULTON ST                         |1    |
# |2100 Block of 37TH AV                       |1    |
# |19TH AV / SAINT CHARLES AV                  |1    |
# |CHENERY ST / CHILTON AV                     |1    |
# |WOODSIDE AV / IDORA AV                      |1    |
# |ULLOA ST / FOREST SIDE AV                   |1    |
# |900 Block of 36TH AV                        |1    |
# |1100 Block of 20TH ST                       |1    |
# |INDUSTRIAL ST / CHARTER OAK AV              |1    |
# |29TH AV / MORAGA ST                         |1    |
# |POPE ST / POLARIS WY                        |1    |
# |NORTHVIEW CT / BAY ST                       |1    |
# |3RD ST / JAMES LICK FREEWAY HY              |1    |
# |CRISP RD / QUESADA AV                       |1    |
# |DONNER AV / BAY SHORE BL                    |1    |
# |KNOTT CT / WATT AV                          |1    |
# |MORAGA ST / 22ND AV                         |1    |
# |1500 Block of BURROWS ST                    |1    |
# |WILMOT ST / STEINER ST                      |1    |
# |LATHROP AV / WHEELER AV                     |1    |
# |SAINT GEORGE AL / BUSH ST                   |1    |
# |SILVER AV / DUNSMUIR ST                     |1    |
# |PORTOLA DR / 15TH AV                        |1    |
# |OCEAN AV / GELLERT DR                       |1    |
# |TREAT AV / ALABAMA ST                       |1    |
# |COTTAGE RW / SUTTER ST                      |1    |
# |BUENA VISTA EAST AV / WALLER ST             |1    |
# |ROLPH ST / NEWTON ST                        |1    |
# |GOETTINGEN ST / HARKNESS AV                 |1    |
# |100 Block of BOWLING GREEN DR               |1    |
# |FOLSOM ST / ERIE ST                         |1    |
# |COLLEGE AV / SAINT MARYS AV                 |1    |
# |CONRAD ST / DIAMOND ST                      |1    |
# |1500 Block of SUNSET BL                     |1    |
# |ULLOA ST / GREAT HWY                        |1    |
# |BACON ST / AMHERST ST                       |1    |
# |ORDWAY ST / SOMERSET ST                     |1    |
# |33RD AV / MORAGA ST                         |1    |
# |40TH AV / KIRKHAM ST                        |1    |
# |800 Block of MIRAMAR AV                     |1    |
# |SAINT CHARLES AV / ALEMANY BL               |1    |
# |IRVING ST / 38TH AV                         |1    |
# |0 Block of ALLEN ST                         |1    |
# |100 Block of MONO ST                        |1    |
# |CHASE CT / COLUSA PL                        |1    |
# |REGENT ST / ALEMANY BL                      |1    |
# |ELWOOD ST / MASON ST                        |1    |
# |0 Block of COLUSA PL                        |1    |
# |MONTALVO AV / DEWEY BL                      |1    |
# |0 Block of EL CAMINO DEL MAR                |1    |
# |ELIZABETH ST / HOFFMAN AV                   |1    |
# |MCALLISTER ST / CHARLES J BRENHAM PLORTH ST |1    |
# +--------------------------------------------+-----+

# %% [markdown]
# ## number of crimes for each category

# %%
train.groupBy("Category").count().orderBy("count", ascending=0).show(100000, truncate=False)
# Out:
# +---------------------------+------+
# |Category                   |count |
# +---------------------------+------+
# |LARCENY/THEFT              |174900|
# |OTHER OFFENSES             |126182|
# |NON-CRIMINAL               |92304 |
# |ASSAULT                    |76876 |
# |DRUG/NARCOTIC              |53971 |
# |VEHICLE THEFT              |53781 |
# |VANDALISM                  |44725 |
# |WARRANTS                   |42214 |
# |BURGLARY                   |36755 |
# |SUSPICIOUS OCC             |31414 |
# |MISSING PERSON             |25989 |
# |ROBBERY                    |23000 |
# |FRAUD                      |16679 |
# |FORGERY/COUNTERFEITING     |10609 |
# |SECONDARY CODES            |9985  |
# |WEAPON LAWS                |8555  |
# |PROSTITUTION               |7484  |
# |TRESPASS                   |7326  |
# |STOLEN PROPERTY            |4540  |
# |SEX OFFENSES FORCIBLE      |4388  |
# |DISORDERLY CONDUCT         |4320  |
# |DRUNKENNESS                |4280  |
# |RECOVERED VEHICLE          |3138  |
# |KIDNAPPING                 |2341  |
# |DRIVING UNDER THE INFLUENCE|2268  |
# |RUNAWAY                    |1946  |
# |LIQUOR LAWS                |1903  |
# |ARSON                      |1513  |
# |LOITERING                  |1225  |
# |EMBEZZLEMENT               |1166  |
# |SUICIDE                    |508   |
# |FAMILY OFFENSES            |491   |
# |BAD CHECKS                 |406   |
# |BRIBERY                    |289   |
# |EXTORTION                  |256   |
# |SEX OFFENSES NON FORCIBLE  |148   |
# |GAMBLING                   |146   |
# |PORNOGRAPHY/OBSCENE MAT    |22    |
# |TREA                       |6     |
# +---------------------------+------+

# %% [markdown]
# ## crime distributions of Districts

# %%
train.groupBy("PdDistrict").count().orderBy("count", ascending=0).show(100000, truncate=False)
# Out:
# +----------+------+
# |PdDistrict|count |
# +----------+------+
# |SOUTHERN  |157182|
# |MISSION   |119908|
# |NORTHERN  |105296|
# |BAYVIEW   |89431 |
# |CENTRAL   |85460 |
# |TENDERLOIN|81809 |
# |INGLESIDE |78845 |
# |TARAVAL   |65596 |
# |PARK      |49313 |
# |RICHMOND  |45209 |
# +----------+------+

# %% [markdown]
# ## crime distribution of weekdays

# %%
train.groupBy("DayOfWeek").count().orderBy("count", ascending=0).show(100000, truncate=False)
# Out:
# +---------+------+
# |DayOfWeek|count |
# +---------+------+
# |Friday   |133734|
# |Wednesday|129211|
# |Saturday |126810|
# |Thursday |125038|
# |Tuesday  |124965|
# |Monday   |121584|
# |Sunday   |116707|
# +---------+------+
